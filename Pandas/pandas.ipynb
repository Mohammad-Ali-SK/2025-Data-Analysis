# %% [markdown]
# # Pandas WS Cube Tech

# %%
import pandas as pd

# %%
data = {"Name":['Ali','Sumon','Sumi','Rup','Ali'],
        "Age":[22,22,20,19,22]}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0    Ali   22
# 1  Sumon   22
# 2   Sumi   20
# 3    Rup   19
# 4    Ali   22

# %%
data = pd.read_csv("../EDA/Churn_Modelling_EDA.csv")
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data['Dependents'].value_counts()
# Out:
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64

# %% [markdown]
# ## 2. Exploring Data in Pandas

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data.shape
# Out:
# (7043, 21)

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ## 3. Handling Duplicate Values in Pandas

# %%
df['Name'].duplicated().sum()
# Out:
# 1

# %% [markdown]
# ###
# - Always remember if you want to find duplicated vale then always chose unique/primary column

# %%
df['Name'].drop_duplicates()
# Out:
# 0      Ali
# 1    Sumon
# 2     Sumi
# 3      Rup
# Name: Name, dtype: object

# %% [markdown]
# ## 4. Working with Missing Data in Pandas

# %%
df = pd.read_csv("../EDA/Churn_Modelling.csv")

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.dropna()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head(3)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1

# %%
data = {"Name":['Ali','Sumon','Sumi','Rup','Ali'],
        "Age":[22,22,20,19,89]}
df2 = pd.DataFrame(data)
print(df2)
# Out:
#     Name  Age
# 0    Ali   22
# 1  Sumon   22
# 2   Sumi   20
# 3    Rup   19
# 4    Ali   89

# %% [markdown]
# # 5. COlumns Transformation in Pandas Part -1

# %%
df2.loc[(df2['Name'] == 'Ali'), "OK"] = "YES"
df2.loc[(df2['Name'] != 'Ali'), "OK"] = "NO"

# %%
df2.head()
# Out:
#     Name  Age   OK
# 0    Ali   22  YES
# 1  Sumon   22   NO
# 2   Sumi   20   NO
# 3    Rup   19   NO
# 4    Ali   89  YES

# %% [markdown]
# # 5. COlumns Transformation in Pandas Part - 2

# %% [markdown]
# ## 6. Group By in Pandas

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
gp = df.groupby("Geography").agg({"Gender":"count"})

# %%
gp.head()
# Out:
#            Gender
# Geography
# France       5014
# Germany      2509
# Spain        2477

# %% [markdown]
# ## Find avg age every country

# %%
gp1 = df.groupby(["Geography","Gender"]).agg({"Age":"mean", "Balance":"max"})

# %%
gp1
# Out:
#                         Age    Balance
# Geography Gender
# France    Female  38.773994  238387.56
#           Male    38.296404  212692.97
# Germany   Female  40.154233  206868.78
#           Male    39.424772  214346.96
# Spain     Female  39.199265  216109.88
#           Male    38.649135  250898.09

# %% [markdown]
# # 7. Merge, Join and Concatenate in Pandas

# %%
data1 = {"Emp ID": ["E01","E02","E03","E04","E05"],
         "Name":["Ali","Sumi","Rup","Roki","Sahin"],
         "Age":[22,45,66,77,40]}

data2 ={"Emp ID": ["E01","E02","E03","E04","E05"],
         "Salary": [33000,56000,60000,34000,78000]}

df1 = pd.DataFrame(data1)
df2  = pd.DataFrame(data2)
df1
# Out:
#   Emp ID   Name  Age
# 0    E01    Ali   22
# 1    E02   Sumi   45
# 2    E03    Rup   66
# 3    E04   Roki   77
# 4    E05  Sahin   40

# %%
df2
# Out:
#   Emp ID  Salary
# 0    E01   33000
# 1    E02   56000
# 2    E03   60000
# 3    E04   34000
# 4    E05   78000

# %%
pd.merge(df1, df2, on='Emp ID')
# Out:
#   Emp ID   Name  Age  Salary
# 0    E01    Ali   22   33000
# 1    E02   Sumi   45   56000
# 2    E03    Rup   66   60000
# 3    E04   Roki   77   34000
# 4    E05  Sahin   40   78000

# %% [markdown]
# # 8. Pandas | Compare DataFrames

# %% [markdown]
# # 9. Pivoting Melting DataFrame
