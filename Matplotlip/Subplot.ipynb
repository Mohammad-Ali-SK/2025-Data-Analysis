# %% [markdown]
# ## Subplot in Matplotlib Python

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]

plt.subplot(2,2,1)
plt.plot(x,y, color = "r")

plt.subplot(2,2,2)
plt.pie([1],colors="r")

x1 = [10,20,30,40]

plt.show()
