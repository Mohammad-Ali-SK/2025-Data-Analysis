# %% [markdown]
# ## Stack Plot

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
area = [9,5,2,7,3]
area1 = [3,8,6,8,1]
area2 = [10,6,7,9,6]

l = ["area","area1","area2"]


plt.stackplot(x,area,area1,area2, labels=l)
plt.legend(loc=1, fontsize=8)
# plt.grid()
plt.show()
