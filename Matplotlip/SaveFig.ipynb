# %% [markdown]
# ## Matplotlib Savefig

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1,2,3,4,5]
y = [2,4,3,6,5]

plt.plot(x,y,color="r")
plt.savefig("line")


plt.show()

# %% [markdown]
# - Te Enhance more quality use ( dpi = 2000)
# - Change background use (facecolor = "g")
# - To save pdf file use (.pdf)
